# %%
import pandas as pd
import numpy as np
import pyarrow

# %% [markdown]
# # Import files

# %%
file1 = "lidar_cable_points_easy.parquet"
file2 = "lidar_cable_points_medium.parquet"
file3 = "lidar_cable_points_hard.parquet"
file4 = "lidar_cable_points_extrahard.parquet"


df1 = pd.read_parquet(file1)
df2 = pd.read_parquet(file2)
df3 = pd.read_parquet(file3)
df4 = pd.read_parquet(file4)

# %%
df1
# Out:
#               x          y          z
# 2211   6.196634 -13.157755  10.582272
# 2905 -10.440643  17.264460  10.926065
# 1411   2.977432  -3.552676  10.072814
# 251    5.924494 -10.974960  10.342501
# 794   -7.062873  12.850664  10.557997
# ...         ...        ...        ...
# 1043  11.752706 -19.651017  11.259984
# 2498  -0.718055  -0.646010  10.018425
# 1938  -9.744563  19.548960  11.272980
# 1621  -2.060735   5.730059  10.090603
# 1070  11.126289 -18.497903  11.070958
#
# [1502 rows x 3 columns]

# %% [markdown]
# # Plot df1 set

# %%
import plotly.graph_objs as go
import plotly.express as px

# %%
fig = px.scatter_3d(df1, x='x', y='y', z='z')

fig.show()

# %%
fig = px.scatter_3d(df4, x='x', y='y', z='z')
fig.show()
print(df1.equals(df4))
# Out:
# False

# %%
from sklearn.cluster import DBSCAN

# %%
from sklearn.cluster import SpectralClustering

# %%
clustering_model = SpectralClustering(n_clusters=6, affinity='nearest_neighbors', n_neighbors=12)
df1['cluster'] = clustering_model.fit_predict(df1)

# Étape 3: Créer la visualisation interactive avec Plotly
fig = px.scatter_3d(df1, x='x', y='y', z='z', color='cluster', symbol='cluster', size_max=1)
fig.show()
# Out:
# C:\Users\Laure\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\manifold\_spectral_embedding.py:273: UserWarning:
#
# Graph is not fully connected, spectral embedding may not work as expected.

# %%
from sklearn.linear_model import LinearRegression
X = df1[['x']]
y = df1['y']

regression_model = LinearRegression()
regression_model.fit(X, y)

# Obtenir les coefficients de la droite (a et b) de l'équation y = ax + b
a = regression_model.coef_[0]
b = regression_model.intercept_

# %%
# Étape 3: Créer une visualisation en 2D pour afficher les points et la droite moyenne ajustée
fig = go.Figure()

# Ajouter les points
fig.add_trace(go.Scatter(
    x=df1['x'],
    y=df1['y'],
    mode='markers',
    marker=dict(size=5, color='blue')
))

# Créer la droite moyenne à partir des coefficients trouvés
x_line = np.linspace(df1['x'].min(), df1['x'].max(), 100)
y_line = a * x_line + b

# Ajouter la droite moyenne à la figure
fig.add_trace(go.Scatter(x=x_line, y=y_line, mode='lines', line=dict(color='red')))

# Afficher la figure
fig.show()
